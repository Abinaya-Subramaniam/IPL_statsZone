# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np

# %%
ipl = pd.read_csv("./processed_ipl_dataset.csv")
ipl.head()
# Out:
#    season        city        date match_type player_of_match  \
# 0    2008   Bengaluru  2008-04-18     League     BB McCullum
# 1    2008  Chandigarh  2008-04-19     League      MEK Hussey
# 2    2008       Delhi  2008-04-19     League     MF Maharoof
# 3    2008      Mumbai  2008-04-20     League      MV Boucher
# 4    2008     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M.Chinnaswamy Stadium  Royal Challengers Bengaluru
# 1  Punjab Cricket Association Stadium, Mohali                 Punjab Kings
# 2                            Feroz Shah Kotla               Delhi Capitals
# 3                    Wankhede Stadium, Mumbai               Mumbai Indians
# 4                       Eden Gardens, Kolkata        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# ## Some Initial Visualizations

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=df, x='season', palette=['#3d9970', '#2ecc40', '#01ff70', '#2e8b57', '#228b22'])
plt.title('Number of Matches Played Each Season', fontsize=14, pad=20)
plt.xlabel('Season', fontsize=12)
plt.ylabel('Number of Matches', fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_21632\3032629158.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='season', palette=['#3d9970', '#2ecc40', '#01ff70', '#2e8b57', '#228b22'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_21632\3032629158.py:2: UserWarning:
# The palette list has fewer values (5) than needed (17) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(data=df, x='season', palette=['#3d9970', '#2ecc40', '#01ff70', '#2e8b57', '#228b22'])

# %%
plt.figure(figsize=(8,8))
df['toss_decision'].value_counts().plot(kind='pie', autopct='%1.1f%%', 
                                      colors=['#d4af37', '#ffffff'],
                                      wedgeprops={'edgecolor': 'red', 'linewidth': 2},
                                      textprops={'fontsize': 12})
plt.title('Toss Decision Distribution\n(Like a Cricket Ball)', fontsize=14, pad=20)
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize=(10,6))
bars = plt.bar(['Won Toss & Match', 'Lost Toss & Match'], 
               [toss_win, toss_loss], 
               color=['#004ba0', '#e53935'])  

for bar in bars:
    bar.set_hatch('///')
    bar.set_edgecolor('black')

plt.title('Impact of Toss on Match Outcome', fontsize=14, pad=15)
plt.ylabel('Number of Matches', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=top_players.values, y=top_players.index, 
            palette=['#d4af37', '#f1c232', '#ffd700', '#e6c229', '#daa520']*2)
plt.title('Top 10 Players with Most "Player of the Match" Awards', fontsize=14, pad=15)
plt.xlabel('Number of Awards', fontsize=12)
plt.ylabel('Player', fontsize=12)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_21632\1810885805.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_players.values, y=top_players.index,

# %%
plt.figure(figsize=(10,6))
ax = df['result'].value_counts().plot(kind='bar', color=['#004ba0', '#d4af37'])
plt.title('Match Results Distribution', fontsize=14, pad=15)
plt.xlabel('Result Type', fontsize=12)
plt.ylabel('Number of Matches', fontsize=12)
plt.xticks(rotation=0)

for spine in ax.spines.values():
    spine.set_visible(False)
ax.set_facecolor('#f5f5f5')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.histplot(data=df, x='result_margin', bins=20, 
             color='#2e8b57', edgecolor='#d4af37', linewidth=1.5)
plt.title('Distribution of Win Margins', fontsize=14, pad=15)
plt.xlabel('Win Margin (Runs/Wickets)', fontsize=12)
plt.ylabel('Number of Matches', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
top_venues = df['venue'].value_counts().head(10)

plt.figure(figsize=(12,6))
sns.barplot(x=top_venues.values, y=top_venues.index, palette='magma')
plt.title('Top 10 Venues by Matches Hosted', fontsize=14)
plt.xlabel('Number of Matches', fontsize=12)
plt.ylabel('Venue', fontsize=12)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_21632\2087199542.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_venues.values, y=top_venues.index, palette='magma')

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=top_cities.values, y=top_cities.index, 
            palette=sns.color_palette("summer", n_colors=15))
plt.title('Top 15 Cities by Matches Hosted', fontsize=14, pad=15)
plt.xlabel('Number of Matches', fontsize=12)
plt.ylabel('City', fontsize=12)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_21632\3140312178.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_cities.values, y=top_cities.index,

# %%
top_cities = df['city'].value_counts().head(15)

plt.figure(figsize=(12,6))
sns.barplot(x=top_cities.values, y=top_cities.index, palette='plasma')
plt.title('Top 15 Cities by Matches Hosted', fontsize=14)
plt.xlabel('Number of Matches', fontsize=12)
plt.ylabel('City', fontsize=12)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_21632\1694455181.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_cities.values, y=top_cities.index, palette='plasma')

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(data=df, x='target_runs', y='result_margin', 
               hue='result', palette=['#e53935', '#2e8b57'], 
               size='target_overs', sizes=(20, 200))
plt.title('Run Target vs. Result Margin (Chasing Analysis)', fontsize=14, pad=15)
plt.xlabel('Target Runs', fontsize=12)
plt.ylabel('Result Margin (Runs/Wickets)', fontsize=12)
plt.axhline(0, color='#d4af37', linestyle='--')  
plt.grid(alpha=0.3)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_21632\1121835947.py:2: UserWarning:
# The palette list has fewer values (2) than needed (4) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(data=df, x='target_runs', y='result_margin',

# %%
top_5_players = df['player_of_match'].value_counts().head(5).index
player_season = df[df['player_of_match'].isin(top_5_players)].groupby(
    ['season', 'player_of_match']).size().unstack()

plt.figure(figsize=(14,7))
player_season.plot(kind='line', marker='o', 
                  color=['#004ba0', '#e53935', '#d4af37', '#2e8b57', '#6a1b9a'],
                  linewidth=2.5)
plt.title('Top 5 Players: POTM Awards by Season', fontsize=14, pad=15)
plt.xlabel('Season', fontsize=12)
plt.ylabel('Number of Awards', fontsize=12)
plt.grid(linestyle='--', alpha=0.7)
plt.legend(title='Player', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
ipl["result"].value_counts()
# Out:
# result
# wickets      578
# runs         498
# tie           14
# no result      5
# Name: count, dtype: int64

# %%
ipl.head()
# Out:
#    season        city        date match_type player_of_match  \
# 0    2008   Bengaluru  2008-04-18     League     BB McCullum
# 1    2008  Chandigarh  2008-04-19     League      MEK Hussey
# 2    2008       Delhi  2008-04-19     League     MF Maharoof
# 3    2008      Mumbai  2008-04-20     League      MV Boucher
# 4    2008     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M.Chinnaswamy Stadium  Royal Challengers Bengaluru
# 1  Punjab Cricket Association Stadium, Mohali                 Punjab Kings
# 2                            Feroz Shah Kotla               Delhi Capitals
# 3                    Wankhede Stadium, Mumbai               Mumbai Indians
# 4                       Eden Gardens, Kolkata        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...
